# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
N = [1000, 10000, 100000]
cols = ['1 maxHit', '2 maxHits', '3 maxHits']

df = pd.DataFrame([[11, 1089,  35629], [12, 1090,  35629], [12, 1090,  35629]], columns=cols);
df.index = N;
df
# Out:
#         1 maxHit  2 maxHits  3 maxHits
# 1000          11       1089      35629
# 10000         12       1090      35629
# 100000        12       1090      35629

# %%
df.plot()
plt.title("Time to Build Blackjack++ Tree", pad=40)
plt.xlabel("Number of CFR Iterations")
plt.ylabel("Time (microseconds)")
plt.show()

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [11, 12, 12]
two_mh = [1089, 1090, 0]
# three_mh = [35629, 0, 0]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
# plt.bar(br2, two_mh, color ='g', width = barWidth,
#         edgecolor ='grey', label ='2 maxHits')
# plt.bar(br3, three_mh, color ='b', width = barWidth,
#         edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("Time to Build Blackjack++ Tree For 1 maxHit", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [11, 12, 12]
two_mh = [1089, 1090, 1089]
# three_mh = [35629, 0, 0]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
plt.bar(br2, two_mh, color ='g', width = barWidth,
        edgecolor ='grey', label ='2 maxHits')
# plt.bar(br3, three_mh, color ='b', width = barWidth,
#         edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("Time to Build Blackjack++ Tree", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [11, 12, 12]
two_mh = [1089, 1090, 1089]
three_mh = [35629, 35629, 35629]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
plt.bar(br2, two_mh, color ='g', width = barWidth,
        edgecolor ='grey', label ='2 maxHits')
plt.bar(br3, three_mh, color ='b', width = barWidth,
        edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("Time to Build Blackjack++ Tree", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()

# %%
### CFR Run Time
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [875, 8255, 84869]
two_mh = [1089, 1090, 0]
# three_mh = [35629, 0, 0]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
# plt.bar(br2, two_mh, color ='g', width = barWidth,
#         edgecolor ='grey', label ='2 maxHits')
# plt.bar(br3, three_mh, color ='b', width = barWidth,
#         edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("CFR Run Time For 1 maxHit", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()

# %%
### CFR Run Time
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [875, 8255, 84869]
two_mh = [75870, 758804, 7588040]
# three_mh = [35629, 0, 0]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
plt.bar(br2, two_mh, color ='g', width = barWidth,
        edgecolor ='grey', label ='2 maxHits')
# plt.bar(br3, three_mh, color ='b', width = barWidth,
#         edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("CFR Run Time", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()

# %%
### CFR Run Time
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
one_mh = [875, 8255, 84869]
two_mh = [75870, 758804, 7588040]
three_mh = [2479406, 24794065, 247940655]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
# br2 = [x + barWidth for x in br1]
# br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, one_mh, color ='r', width = barWidth,
        edgecolor ='grey', label ='1 maxHit')
plt.bar(br2, two_mh, color ='g', width = barWidth,
        edgecolor ='grey', label ='2 maxHits')
plt.bar(br3, three_mh, color ='b', width = barWidth,
        edgecolor ='grey', label ='3 maxHits')
 
# Adding Xticks
plt.title("CFR Run Time", pad=40,  fontweight ='bold', fontsize = 15)
plt.xlabel('Number of CFR Iterations', fontweight ='bold', fontsize = 15)
plt.ylabel('Time (milliseconds)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['1000', '10000', '100000'])
 
plt.legend()
plt.show()
